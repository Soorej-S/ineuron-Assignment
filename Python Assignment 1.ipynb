# %%
#1

m = []
for i in range(2000,3201):
    if i%7 == 0 and i%5 != 0:
        m.append(i)

# %%
#2

first = input("Input your First Name:")
last = input("Input your Last Name:")
print (last + " " + first)
# Out:
# Input your First Name:soorej
# Input your Last Name:s
# s soorej

# %%
#3

d = 12

v = 4/3*22/7*d*d*d
print("volume of a sphere is",v)
# Out:
# volume of a sphere is 7241.142857142859
