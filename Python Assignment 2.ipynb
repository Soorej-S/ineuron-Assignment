# %%
# 1. Create the below pattern using nested for loop in Python.

n=5

for i in range(n):
    for j in range(i):
        print ('*', end=" ")
    print('')

for i in range(n,0,-1):
    for j in range(i):
        print('*', end=" ")
    print('')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
# 2. Write a Python program to reverse a word after accepting the input from the user.

a = list(input("Please give your word to reverse: "))

for i in range(len(a)-1,-1,-1):
    print(a[i], end="")
# Out:
# Please give your word to reverse: ineuron
# norueni
