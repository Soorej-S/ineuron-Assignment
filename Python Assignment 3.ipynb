# %%
# 1.1 Write a Python Program to implement your own myreduce() function which works exactly like Python's built-in function reduce()

def add(a, b):
    return a+b

s = [1,2,3,4,5,6]

def myreduce(fun,seq):
    a = seq[0]  
    for b in seq[1:]:
        a = fun(a, b)
    return a

print( myreduce(add, s))
# Out:
# 21

# %%
# 1.2 Write a Python program to implement your own myfilter() function which works exactly ike Python's built-in function filter()

def myfilter(fun,seq):
    return is_even(a)

a=[1,2,3,4,5,6]
b=[]

def is_even(a):
    for i in a:
        if i%2==0:
            b.append(i)
    print(b)
    
myfilter(is_even,a)
# Out:
# [2, 4, 6]

# %%
# 2. Implement List comprehensions to produce the following lists.

[i*j for i in ['x','y','z'] for j in range(1,5,1)]
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %%
[i*j for i in range(1,5,1) for j in ['x','y','z']]
# Out:
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']

# %%
[[i+j] for i in [2,3,4] for j in range(0,3)]
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

# %%
[[i+j for i in [2,3,4,5]] for j in range(0,3)]
# Out:
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7]]

# %%
[(j,i) for i in [1,2,3] for j in [1,2,3]]
# Out:
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]
